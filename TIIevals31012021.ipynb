# %%
# !pip install odfpy

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pandas import DataFrame, read_csv
import pandas as pd 

file = r'evaltii.ods'
df = pd.read_excel(file)


metric='success'

cadrl = {}
arena = {}
dwa = {}
teb = {}
mpc = {}
#number of velocities
j=3
i=0
while (i < j):
  cadrl["cadrl0{0}".format(i+1)] = [df[metric +'01'][i], df[metric+'02'][i], df[metric+'03'][i]]
  arena["arena0{0}".format(i+1)] = [df[metric +'01'][i+j], df[metric+'02'][i+j], df[metric+'03'][i+j]]
  dwa["dwa0{0}".format(i+1)] = [df[metric +'01'][i+2*j], df[metric+'02'][i+2*j], df[metric+'03'][i+2*j]]
  teb["teb0{0}".format(i+1)] = [df[metric +'01'][i+3*j], df[metric+'02'][i+3*j], df[metric+'03'][i+3*j]]
  mpc["mpc0{0}".format(i+1)] = [df[metric +'01'][i+4*j], df[metric+'02'][i+4*j], df[metric+'03'][i+4*j]]
  i += 1

# %%
mpc
# Out:
# {'mpc01': [100, 100, 98], 'mpc02': [100, 95, 96], 'mpc03': [93, 90, 75]}

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pandas import DataFrame, read_csv
import pandas as pd 

file = r'evaltii.ods'
df = pd.read_excel(file)


metric='success'

cadrl = {}
arena = {}
dwa = {}
teb = {}
mpc = {}
#number of velocities
j=3
i=0
while (i < j):
  cadrl["cadrl0{0}".format(i+1)] = [df[metric +'01'][i], df[metric+'02'][i], df[metric+'03'][i]]
  arena["arena0{0}".format(i+1)] = [df[metric +'01'][i+j], df[metric+'02'][i+j], df[metric+'03'][i+j]]
  dwa["dwa0{0}".format(i+1)] = [df[metric +'01'][i+2*j], df[metric+'02'][i+2*j], df[metric+'03'][i+2*j]]
  teb["teb0{0}".format(i+1)] = [df[metric +'01'][i+3*j], df[metric+'02'][i+3*j], df[metric+'03'][i+3*j]]
  mpc["mpc0{0}".format(i+1)] = [df[metric +'01'][i+4*j], df[metric+'02'][i+4*j], df[metric+'03'][i+4*j]]
  i += 1

# Set position of bar on X axis
r1 = np.arange(3)
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]
r6 = [x + barWidth for x in r5]

colorCADRL = "tab:red"
colorARENA = "tab:purple"
colorDWA = "tab:blue"
colorTEB = "tab:orange"
colorMPC = "tab:green"

fig, ax = plt.subplots()
rects1 = ax.bar(r1, dwa["dwa01"], width=barWidth, label='dwa',  color=colorDWA, alpha=0.3, ecolor='black',capsize=2)
rects2 = ax.bar(r2, teb["teb01"], width=barWidth, label='teb',  color=colorTEB, alpha=0.3, ecolor='black',capsize=2)
rects3 = ax.bar(r3, mpc["mpc01"], width=barWidth, label='mpc',  color=colorMPC, alpha=0.3, ecolor='black',capsize=2)
rects4 = ax.bar(r4, cadrl["cadrl01"], width=barWidth, label='cadrl',  color=colorCADRL, alpha=0.3, ecolor='black',capsize=2)
rects5 = ax.bar(r5, arena["arena01"], width=barWidth, label='arena2d',  color=colorARENA, alpha=0.3, ecolor='black',capsize=2)


rects6 = ax.bar(r1, dwa["dwa02"], width=barWidth,   color=colorDWA, alpha=0.6)
rects7 = ax.bar(r2, teb["teb02"], width=barWidth,  color=colorTEB, alpha=0.6)
rects8 = ax.bar(r3, mpc["mpc02"], width=barWidth,   color=colorMPC, alpha=0.6)
rects9 = ax.bar(r4, cadrl["cadrl02"], width=barWidth,  color=colorCADRL, alpha=0.6)
rects10 = ax.bar(r5, arena["arena02"], width=barWidth,   color=colorARENA, alpha=0.6)


rects11 = ax.bar(r1, dwa["dwa03"], width=barWidth, color=colorDWA, alpha=1)
rects12 = ax.bar(r2, teb["teb03"], width=barWidth,   color=colorTEB, alpha=1)
rects13 = ax.bar(r3, mpc["mpc03"], width=barWidth,   color=colorMPC, alpha=1)
rects14 = ax.bar(r4, cadrl["cadrl03"], width=barWidth,   color=colorCADRL, alpha=1)
rects15 = ax.bar(r5, arena["arena03"], width=barWidth,   color=colorARENA, alpha=1)

# Add xticks on the middle of the group bars
plt.xlabel('Number of dyn. Obstacles', fontsize=15)
plt.xticks([r + 2*barWidth for r in range(3)], ['5', '10', '20'])
plt.ylabel('Success Rate', fontsize=15)
plt.title("Success Rate over Number of dynamic Obstacles", fontweight='bold', fontsize=16)
 
# Create legend & Showt graphic
#plt.legend(loc='upper right')
plt.savefig('success.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-dd334272183b> in <module>()
#      29 # Set position of bar on X axis
#      30 r1 = np.arange(3)
# ---> 31 r2 = [x + barWidth for x in r1]
#      32 r3 = [x + barWidth for x in r2]
#      33 r4 = [x + barWidth for x in r3]
#
# <ipython-input-83-dd334272183b> in <listcomp>(.0)
#      29 # Set position of bar on X axis
#      30 r1 = np.arange(3)
# ---> 31 r2 = [x + barWidth for x in r1]
#      32 r3 = [x + barWidth for x in r2]
#      33 r4 = [x + barWidth for x in r3]
#
# NameError: name 'barWidth' is not defined

# %%
cadrl, teb , arena, mpc
# Out:
# ({'cadrl01': [100, 100, 92], 'cadrl02': [98, 90, 86], 'cadrl03': [82, 65, 60]},
#  {'teb01': [100, 100, 95], 'teb02': [100, 84, 95], 'teb03': [93, 85, 70]},
#  {'arena01': [100, 100, 93],
#   'arena02': [100, 91, 88],
#   'arena03': [95, 93, 75]},
#  {'mpc01': [100, 100, 98], 'mpc02': [100, 95, 96], 'mpc03': [93, 90, 75]})

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pandas import DataFrame, read_csv
import pandas as pd 

file = r'evaltii.ods'
df = pd.read_excel(file)


metric='time'

cadrl = {}
arena = {}
dwa = {}
teb = {}
mpc = {}
#number of velocities
j=3
i=0
while (i < j):
  cadrl["cadrl0{0}".format(i+1)] = [df[metric +'01'][i], df[metric+'02'][i], df[metric+'03'][i]]
  arena["arena0{0}".format(i+1)] = [df[metric +'01'][i+j], df[metric+'02'][i+j], df[metric+'03'][i+j]]
  dwa["dwa0{0}".format(i+1)] = [df[metric +'01'][i+2*j], df[metric+'02'][i+2*j], df[metric+'03'][i+2*j]]
  teb["teb0{0}".format(i+1)] = [df[metric +'01'][i+3*j], df[metric+'02'][i+3*j], df[metric+'03'][i+3*j]]
  mpc["mpc0{0}".format(i+1)] = [df[metric +'01'][i+4*j], df[metric+'02'][i+4*j], df[metric+'03'][i+4*j]]
  i += 1

# Set position of bar on X axis
r1 = np.arange(3)
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]
r6 = [x + barWidth for x in r5]

colorCADRL = "tab:red"
colorARENA = "tab:purple"
colorDWA = "tab:blue"
colorTEB = "tab:orange"
colorMPC = "tab:green"

fig, ax = plt.subplots()
rects11 = ax.bar(r1, dwa["dwa03"], width=barWidth, color=colorDWA, alpha=0.3)
rects12 = ax.bar(r2, teb["teb03"], width=barWidth,   color=colorTEB, alpha=0.3)
rects13 = ax.bar(r3, mpc["mpc03"], width=barWidth,   color=colorMPC, alpha=0.3)
rects14 = ax.bar(r4, cadrl["cadrl03"], width=barWidth,   color=colorCADRL, alpha=0.3)
rects15 = ax.bar(r5, arena["arena03"], width=barWidth,   color=colorARENA, alpha=0.3)

rects6 = ax.bar(r1, dwa["dwa02"], width=barWidth,   color=colorDWA, alpha=0.6)
rects7 = ax.bar(r2, teb["teb02"], width=barWidth,  color=colorTEB, alpha=0.6)
rects8 = ax.bar(r3, mpc["mpc02"], width=barWidth,   color=colorMPC, alpha=0.6)
rects9 = ax.bar(r4, cadrl["cadrl02"], width=barWidth,  color=colorCADRL, alpha=0.6)
rects10 = ax.bar(r5, arena["arena02"], width=barWidth,   color=colorARENA, alpha=0.6)

rects1 = ax.bar(r1, dwa["dwa01"], width=barWidth, label='dwa',  color=colorDWA, alpha=1, ecolor='black',capsize=2)
rects2 = ax.bar(r2, teb["teb01"], width=barWidth, label='teb',  color=colorTEB, alpha=1, ecolor='black',capsize=2)
rects3 = ax.bar(r3, mpc["mpc01"], width=barWidth, label='mpc',  color=colorMPC, alpha=1, ecolor='black',capsize=2)
rects4 = ax.bar(r4, cadrl["cadrl01"], width=barWidth, label='cadrl',  color=colorCADRL, alpha=1, ecolor='black',capsize=2)
rects5 = ax.bar(r5, arena["arena01"], width=barWidth, label='arena2d',  color=colorARENA, alpha=1, ecolor='black',capsize=2)

# Add xticks on the middle of the group bars
plt.xlabel('Number of dyn. Obstacles', fontsize=15)
plt.xticks([r + barWidth for r in range(3)], ['5', '10', '20'])
plt.ylabel('Time t.g. [s]', fontsize=15)
plt.title("Time t.g. over Number of dynamic Obstacles", fontweight='bold', fontsize=16)
 
# Create legend & Showt graphic
#plt.legend(loc='upper right')
plt.savefig('time.png')
plt.show()

# %%
cadrl["cadrl02"]
# Out:
# [0, 11, 57]

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pandas import DataFrame, read_csv
import pandas as pd 

file = r'evaltii.ods'
df = pd.read_excel(file)


metric='collisions'

cadrl = {}
arena = {}
dwa = {}
teb = {}
mpc = {}
#number of velocities
j=3
i=0
while (i < j):
  cadrl["cadrl0{0}".format(i+1)] = [df[metric +'01'][i], df[metric+'02'][i], df[metric+'03'][i]]
  arena["arena0{0}".format(i+1)] = [df[metric +'01'][i+j], df[metric+'02'][i+j], df[metric+'03'][i+j]]
  dwa["dwa0{0}".format(i+1)] = [df[metric +'01'][i+2*j], df[metric+'02'][i+2*j], df[metric+'03'][i+2*j]]
  teb["teb0{0}".format(i+1)] = [df[metric +'01'][i+3*j], df[metric+'02'][i+3*j], df[metric+'03'][i+3*j]]
  mpc["mpc0{0}".format(i+1)] = [df[metric +'01'][i+4*j], df[metric+'02'][i+4*j], df[metric+'03'][i+4*j]]
  i += 1

# Set position of bar on X axis
r1 = np.arange(3)
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]
r6 = [x + barWidth for x in r5]

colorCADRL = "tab:red"
colorARENA = "tab:purple"
colorDWA = "tab:blue"
colorTEB = "tab:orange"
colorMPC = "tab:green"

fig, ax = plt.subplots()
rects11 = ax.bar(r1, dwa["dwa03"], width=barWidth, color=colorDWA, alpha=0.3)
rects12 = ax.bar(r2, teb["teb03"], width=barWidth,   color=colorTEB, alpha=0.3)
rects13 = ax.bar(r3, mpc["mpc03"], width=barWidth,   color=colorMPC, alpha=0.3)
rects14 = ax.bar(r4, cadrl["cadrl03"], width=barWidth,   color=colorCADRL, alpha=0.3)
rects15 = ax.bar(r5, arena["arena03"], width=barWidth,   color=colorARENA, alpha=0.3)

rects6 = ax.bar(r1, dwa["dwa02"], width=barWidth,   color=colorDWA, alpha=0.6)
rects7 = ax.bar(r2, teb["teb02"], width=barWidth,  color=colorTEB, alpha=0.6)
rects8 = ax.bar(r3, mpc["mpc02"], width=barWidth,   color=colorMPC, alpha=0.6)
rects9 = ax.bar(r4, cadrl["cadrl02"], width=barWidth,  color=colorCADRL, alpha=0.6)
rects10 = ax.bar(r5, arena["arena02"], width=barWidth,   color=colorARENA, alpha=0.6)

rects1 = ax.bar(r1, dwa["dwa01"], width=barWidth, label='dwa',  color=colorDWA, alpha=1, ecolor='black',capsize=2)
rects2 = ax.bar(r2, teb["teb01"], width=barWidth, label='teb',  color=colorTEB, alpha=1, ecolor='black',capsize=2)
rects3 = ax.bar(r3, mpc["mpc01"], width=barWidth, label='mpc',  color=colorMPC, alpha=1, ecolor='black',capsize=2)
rects4 = ax.bar(r4, cadrl["cadrl01"], width=barWidth, label='cadrl',  color=colorCADRL, alpha=1, ecolor='black',capsize=2)
rects5 = ax.bar(r5, arena["arena01"], width=barWidth, label='arena2d',  color=colorARENA, alpha=1, ecolor='black',capsize=2)

# Add xticks on the middle of the group bars
plt.xlabel('Number of dyn. Obstacles', fontsize=15)
plt.xticks([r + barWidth for r in range(3)], ['5', '10', '20'])
plt.ylabel('Collisions', fontsize=15)
plt.title("Collisions over Number of dynamic Obstacles", fontweight='bold', fontsize=16)
 
# Create legend & Showt graphic
plt.legend(loc='upper right')
plt.savefig('collisions.png')
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pandas import DataFrame, read_csv
import pandas as pd 

file = r'evaltii.ods'
df = pd.read_excel(file)


metric='path'

cadrl = {}
arena = {}
dwa = {}
teb = {}
mpc = {}
#number of velocities
j=3
i=0
while (i < j):
  cadrl["cadrl0{0}".format(i+1)] = [df[metric +'01'][i], df[metric+'02'][i], df[metric+'03'][i]]
  arena["arena0{0}".format(i+1)] = [df[metric +'01'][i+j], df[metric+'02'][i+j], df[metric+'03'][i+j]]
  dwa["dwa0{0}".format(i+1)] = [df[metric +'01'][i+2*j], df[metric+'02'][i+2*j], df[metric+'03'][i+2*j]]
  teb["teb0{0}".format(i+1)] = [df[metric +'01'][i+3*j], df[metric+'02'][i+3*j], df[metric+'03'][i+3*j]]
  mpc["mpc0{0}".format(i+1)] = [df[metric +'01'][i+4*j], df[metric+'02'][i+4*j], df[metric+'03'][i+4*j]]
  i += 1

# Set position of bar on X axis
r1 = np.arange(3)
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]
r6 = [x + barWidth for x in r5]

colorCADRL = "tab:red"
colorARENA = "tab:purple"
colorDWA = "tab:blue"
colorTEB = "tab:orange"
colorMPC = "tab:green"

fig, ax = plt.subplots()
rects11 = ax.bar(r1, dwa["dwa03"], width=barWidth, color=colorDWA, alpha=0.3)
rects12 = ax.bar(r2, teb["teb03"], width=barWidth,   color=colorTEB, alpha=0.3)
rects13 = ax.bar(r3, mpc["mpc03"], width=barWidth,   color=colorMPC, alpha=0.3)
rects14 = ax.bar(r4, cadrl["cadrl03"], width=barWidth,   color=colorCADRL, alpha=0.3)
rects15 = ax.bar(r5, arena["arena03"], width=barWidth,   color=colorARENA, alpha=0.3)

rects6 = ax.bar(r1, dwa["dwa02"], width=barWidth,   color=colorDWA, alpha=0.6)
rects7 = ax.bar(r2, teb["teb02"], width=barWidth,  color=colorTEB, alpha=0.6)
rects8 = ax.bar(r3, mpc["mpc02"], width=barWidth,   color=colorMPC, alpha=0.6)
rects9 = ax.bar(r4, cadrl["cadrl02"], width=barWidth,  color=colorCADRL, alpha=0.6)
rects10 = ax.bar(r5, arena["arena02"], width=barWidth,   color=colorARENA, alpha=0.6)

rects1 = ax.bar(r1, dwa["dwa01"], width=barWidth, label='dwa',  color=colorDWA, alpha=1, ecolor='black',capsize=2)
rects2 = ax.bar(r2, teb["teb01"], width=barWidth, label='teb',  color=colorTEB, alpha=1, ecolor='black',capsize=2)
rects3 = ax.bar(r3, mpc["mpc01"], width=barWidth, label='mpc',  color=colorMPC, alpha=1, ecolor='black',capsize=2)
rects4 = ax.bar(r4, cadrl["cadrl01"], width=barWidth, label='cadrl',  color=colorCADRL, alpha=1, ecolor='black',capsize=2)
rects5 = ax.bar(r5, arena["arena01"], width=barWidth, label='arena2d',  color=colorARENA, alpha=1, ecolor='black',capsize=2)

# Add xticks on the middle of the group bars
plt.xlabel('Number of dyn. Obstacles', fontsize=15)
plt.xticks([r + barWidth for r in range(3)], ['5', '10', '20'])
plt.ylabel('avg. Path Length [m]', fontsize=15)
plt.title("avg. Path Length over Number of dynamic Obstacles", fontweight='bold', fontsize=16)
 
# Create legend & Showt graphic
#plt.legend(loc='upper right')
plt.savefig('Path.png')
plt.show()

# %%
# x axis values 
y = [0.97,0.88,0.72] 
y1 = [0.78,0.77,0.73] 
y2 = [1.12,0.934,0.921] 
y3 = [1.291,0.98,0.99] 
# corresponding y axis values 
x = [0.1,0.2,0.3] 
  
# plotting the points  
plt.plot(x, y) 
plt.plot(x, y1) 
plt.plot(x, y2) 
plt.plot(x, y3) 

colorCADRL = "tab:red"
colorARENA = "tab:purple"
colorDWA = "tab:blue"
colorTEB = "tab:orange"
colorMPC = "tab:green"

fig, ax = plt.subplots()
ax.plot(x, y,marker = 'o', label='cadrl',  color=colorCADRL, alpha=1)
ax.plot(x, y1,marker = 'x', label='dwa',  color=colorDWA, alpha=1)
ax.plot(x, y2,marker = '+', label='teb',  color=colorTEB, alpha=1)
ax.plot(x, y3,marker = 'X', label='mpc',   color=colorMPC, alpha=1)


ax.hlines(y=1, xmin=0.1, xmax=0.3, linewidth=2, color=colorARENA, linestyles='dashed')
ax.text(0.1, 1.02, r'Arena Baseline', fontsize=10)
# naming the x axis 
plt.xlabel('Dyn. Obstacle Velocity', fontsize=15) 
# naming the y axis 
plt.ylabel('Percentage [%]', fontsize=15) 
  
# giving a title to my graph 
plt.title('Relative Performance to Arena', fontsize=15) 
  

# Create legend & Showt graphic
plt.legend(loc='upper right')
plt.savefig('{0}vel_{1}.png'.format(metric, map))
# function to show the plot 
plt.show()

# %%
# !pip install odfpy
# Out:
# ...
#      |████████████████████████████████| 727kB 8.0MB/s
# ...
#   Created wheel for odfpy: filename=odfpy-1.4.1-py2.py3-none-any.whl size=160691 sha256=30cce78558a1bef205dc94730ae5f2858dd0510bebe2ee4dabdd005cc0a20a12
#   Stored in directory: /root/.cache/pip/wheels/ce/6b/93/ec330f2991c5f1546abf640360e5a2022f76cb16e5d99ed2fd
# Successfully built odfpy
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pandas import DataFrame, read_csv
import pandas as pd 

file = r'evaltii.ods'
df = pd.read_excel(file)

file2 = r'eval2.ods'
df2 = pd.read_excel(file2)


metric='collisions'

cadrl = {}
arena = {}
dwa = {}
teb = {}
mpc = {}
cadrl2 = {}
arena2 = {}
dwa2 = {}
teb2 = {}
mpc2 = {}
#number of velocities
j=3
i=1
while (i <= j):
  cadrl["cadrl0{0}".format(i+1)] = [df[metric +'0{0}'.format(i)][0], df[metric+'0{0}'.format(i)][1], df[metric+'0{0}'.format(i)][2]]
  arena["arena0{0}".format(i+1)] = [df[metric +'0{0}'.format(i)][3], df[metric+'0{0}'.format(i)][4], df[metric+'0{0}'.format(i)][5]]
  dwa["dwa0{0}".format(i+1)] = [df[metric +'0{0}'.format(i)][6], df[metric+'0{0}'.format(i)][7], df[metric+'0{0}'.format(i)][8]]
  teb["teb0{0}".format(i+1)] = [df[metric +'0{0}'.format(i)][9], df[metric+'0{0}'.format(i)][10], df[metric+'0{0}'.format(i)][11]]
  mpc["mpc0{0}".format(i+1)] = [df[metric +'0{0}'.format(i)][12], df[metric+'0{0}'.format(i)][13], df[metric+'0{0}'.format(i)][14]]

  cadrl2["cadrl0{0}".format(i+1)] = [df2[metric +'0{0}'.format(i)][0], df2[metric+'0{0}'.format(i)][1], df2[metric+'0{0}'.format(i)][2]]
  arena2["arena0{0}".format(i+1)] = [df2[metric +'0{0}'.format(i)][3], df2[metric+'0{0}'.format(i)][4], df2[metric+'0{0}'.format(i)][5]]
  dwa2["dwa0{0}".format(i+1)] = [df2[metric +'0{0}'.format(i)][6], df2[metric+'0{0}'.format(i)][7], df2[metric+'0{0}'.format(i)][8]]
  teb2["teb0{0}".format(i+1)] = [df2[metric +'0{0}'.format(i)][9], df2[metric+'0{0}'.format(i)][10], df2[metric+'0{0}'.format(i)][11]]
  mpc2["mpc0{0}".format(i+1)] = [df2[metric +'0{0}'.format(i)][12], df2[metric+'0{0}'.format(i)][13], df2[metric+'0{0}'.format(i)][14]]
  i += 1

# %%
(
(sum(cadrl2["cadrl04"])+ sum(cadrl["cadrl04"])+sum(cadrl2["cadrl03"])+ sum(cadrl["cadrl03"])+sum(cadrl2["cadrl02"])+ sum(cadrl["cadrl02"]))/18,
(sum(arena2["arena04"])+ sum(arena["arena04"])+sum(arena2["arena03"])+ sum(arena["arena03"])+sum(arena2["arena02"])+ sum(arena["arena02"]))/18,
(sum(dwa2["dwa04"])+ sum(dwa["dwa04"])+sum(dwa2["dwa03"])+ sum(dwa["dwa03"])+sum(dwa2["dwa02"])+ sum(dwa["dwa02"]))/18,
(sum(mpc2["mpc04"])+ sum(mpc["mpc04"])+sum(mpc2["mpc03"])+ sum(mpc["mpc03"])+sum(mpc2["mpc02"])+ sum(mpc["mpc02"]))/18,
(sum(teb2["teb04"])+ sum(teb["teb04"])+sum(teb2["teb03"])+ sum(teb["teb03"])+sum(teb2["teb02"])+ sum(teb["teb02"]))/18)
# Out:
# (41.333333333333336,
#  19.88888888888889,
#  70.66666666666667,
#  24.88888888888889,
#  23.88888888888889)

# %%
(
(sum(cadrl["cadrl04"])+ sum(cadrl["cadrl03"])+ sum(cadrl["cadrl02"]))/9,
(sum(arena["arena04"])+ sum(arena["arena03"])+ sum(arena["arena02"]))/9,
(sum(dwa["dwa04"])+ sum(dwa["dwa03"])+ sum(dwa["dwa02"]))/9,
(sum(mpc["mpc04"])+sum(mpc["mpc03"])+ sum(mpc["mpc02"]))/9,
(sum(teb["teb04"])+ sum(teb["teb03"])+ sum(teb["teb02"]))/9)
# Out:
# (49.111111111111114,
#  23.77777777777778,
#  65.66666666666667,
#  18.666666666666668,
#  26.77777777777778)

# %%
(
    (sum(cadrl2["cadrl04"])+ sum(cadrl2["cadrl03"])+ sum(cadrl2["cadrl02"]))/9,
    (sum(arena2["arena04"])+ sum(arena2["arena03"])+ sum(arena2["arena02"]))/9,
(sum(dwa2["dwa04"])+ sum(dwa2["dwa03"])+ sum(dwa2["dwa02"]))/9,
(sum(mpc2["mpc04"])+sum(mpc2["mpc03"])+ sum(mpc2["mpc02"]))/9,

(sum(teb2["teb04"])+ sum(teb2["teb03"])+ sum(teb2["teb02"]))/9)
# Out:
# (33.55555555555556, 16.0, 75.66666666666667, 31.11111111111111, 21.0)

# %%
# !pip install odmpy

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pandas import DataFrame, read_csv
import pandas as pd 

file = r'eval2.ods'
df = pd.read_excel(file)

map="map2"
metrics=['collisions', 'success', 'time', 'path']

barWidth = 0.1

for metric in metrics:
  
  cadrl = {}
  arena = {}
  dwa = {}
  teb = {}
  mpc = {}
  #number of velocities
  j=3
  i=1
  while (i <= j):
    cadrl["cadrl0{0}".format(i+1)] = [df[metric +'0{0}'.format(i)][0], df[metric+'0{0}'.format(i)][1], df[metric+'0{0}'.format(i)][2]]
    arena["arena0{0}".format(i+1)] = [df[metric +'0{0}'.format(i)][3], df[metric+'0{0}'.format(i)][4], df[metric+'0{0}'.format(i)][5]]
    dwa["dwa0{0}".format(i+1)] = [df[metric +'0{0}'.format(i)][6], df[metric+'0{0}'.format(i)][7], df[metric+'0{0}'.format(i)][8]]
    mpc["mpc0{0}".format(i+1)] = [df[metric +'0{0}'.format(i)][9], df[metric+'0{0}'.format(i)][10], df[metric+'0{0}'.format(i)][11]]
    teb["teb0{0}".format(i+1)] = [df[metric +'0{0}'.format(i)][12], df[metric+'0{0}'.format(i)][13], df[metric+'0{0}'.format(i)][14]]
    i += 1

  # Set position of bar on X axis
  r1 = np.arange(3)
  r2 = [x + barWidth for x in r1]
  r3 = [x + barWidth for x in r2]
  r4 = [x + barWidth for x in r3]
  r5 = [x + barWidth for x in r4]
  r6 = [x + barWidth for x in r5]


  colorCADRL = "tab:red"
  colorARENA = "tab:purple"
  colorDWA = "tab:blue"
  colorTEB = "tab:orange"
  colorMPC = "tab:green"

  fig, ax = plt.subplots()
  rects1 = ax.bar(r1, cadrl["cadrl04"], width=barWidth, label='dwa',  color=colorDWA, alpha=1, ecolor='black',capsize=2)
  rects2 = ax.bar(r2, teb["teb04"], width=barWidth, label='teb',  color=colorTEB, alpha=1, ecolor='black',capsize=2)
  rects3 = ax.bar(r3, mpc["mpc04"], width=barWidth, label='mpc',  color=colorMPC, alpha=1, ecolor='black',capsize=2)
  rects4 = ax.bar(r4, cadrl["cadrl04"], width=barWidth, label='cadrl',  color=colorCADRL, alpha=1, ecolor='black',capsize=2)
  rects5 = ax.bar(r5, arena["arena04"], width=barWidth, label='arena2d',  color=colorARENA, alpha=1, ecolor='black',capsize=2)


  #captions
  caption = ""
  if metric == "path":
    caption = "avg. Path Lenght [m]"
    title = "Path Lenght"
  if metric == "time":
    caption = "avg. Time t.g. [s]"
    title = "Time t.g."
  if metric == "success":
    caption = "Success"
    title = caption
  if metric == "collisions":
    caption = "Collisions"
    title = caption

  # Add xticks on the middle of the group bars
  plt.xlabel('Obstacle Velocity', fontsize=15)
  plt.xticks([r + 2*barWidth for r in range(3)], ['0.1', '0.2', '0.3'])
  plt.ylabel('{}'.format(caption), fontsize=15)
  plt.title("{} over Obstacle Velocity".format(title), fontweight='bold', fontsize=16)

  ax.grid('on')
  # Create legend & Showt graphic
  plt.legend(loc='upper left')
  plt.savefig('{0}vel_{1}.png'.format(metric, map))
  plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pandas import DataFrame, read_csv
import pandas as pd 

file = r'eval2.ods'
df = pd.read_excel(file)

map="map2"
metrics=['collisions', 'success', 'time', 'path']

for metric in metrics:

  cadrl = {}
  arena = {}
  dwa = {}
  teb = {}
  mpc = {}
  #number of velocities
  j=3
  i=0
  while (i < j):
    cadrl["cadrl0{0}".format(i+1)] = [df[metric +'01'][i], df[metric+'02'][i], df[metric+'03'][i]]
    arena["arena0{0}".format(i+1)] = [df[metric +'01'][i+j], df[metric+'02'][i+j], df[metric+'03'][i+j]]
    dwa["dwa0{0}".format(i+1)] = [df[metric +'01'][i+2*j], df[metric+'02'][i+2*j], df[metric+'03'][i+2*j]]
    mpc["mpc0{0}".format(i+1)] = [df[metric +'01'][i+3*j], df[metric+'02'][i+3*j], df[metric+'03'][i+3*j]]
    teb["teb0{0}".format(i+1)] = [df[metric +'01'][i+4*j], df[metric+'02'][i+4*j], df[metric+'03'][i+4*j]]
    i += 1

  # Set position of bar on X axis
  r1 = np.arange(3)
  r2 = [x + barWidth for x in r1]
  r3 = [x + barWidth for x in r2]
  r4 = [x + barWidth for x in r3]
  r5 = [x + barWidth for x in r4]
  r6 = [x + barWidth for x in r5]

  colorCADRL = "tab:red"
  colorARENA = "tab:purple"
  colorDWA = "tab:blue"
  colorTEB = "tab:orange"
  colorMPC = "tab:green"

  if metric == "success":
    fig, ax = plt.subplots()
    rects1 = ax.bar(r1, dwa["dwa01"], width=barWidth, label='dwa',  color=colorDWA, alpha=0.3, ecolor='black',capsize=2)
    rects2 = ax.bar(r2, teb["teb01"], width=barWidth, label='teb',  color=colorTEB, alpha=0.3, ecolor='black',capsize=2)
    rects3 = ax.bar(r3, mpc["mpc01"], width=barWidth, label='mpc',  color=colorMPC, alpha=0.3, ecolor='black',capsize=2)
    rects4 = ax.bar(r4, cadrl["cadrl01"], width=barWidth, label='cadrl',  color=colorCADRL, alpha=0.3, ecolor='black',capsize=2)
    rects5 = ax.bar(r5, arena["arena01"], width=barWidth, label='arena2d',  color=colorARENA, alpha=0.3, ecolor='black',capsize=2)


    rects6 = ax.bar(r1, dwa["dwa02"], width=barWidth,   color=colorDWA, alpha=0.6)
    rects7 = ax.bar(r2, teb["teb02"], width=barWidth,  color=colorTEB, alpha=0.6)
    rects8 = ax.bar(r3, mpc["mpc02"], width=barWidth,   color=colorMPC, alpha=0.6)
    rects9 = ax.bar(r4, cadrl["cadrl02"], width=barWidth,  color=colorCADRL, alpha=0.6)
    rects10 = ax.bar(r5, arena["arena02"], width=barWidth,   color=colorARENA, alpha=0.6)


    rects11 = ax.bar(r1, dwa["dwa03"], width=barWidth, color=colorDWA, alpha=1)
    rects12 = ax.bar(r2, teb["teb03"], width=barWidth,   color=colorTEB, alpha=1)
    rects13 = ax.bar(r3, mpc["mpc03"], width=barWidth,   color=colorMPC, alpha=1)
    rects14 = ax.bar(r4, cadrl["cadrl03"], width=barWidth,   color=colorCADRL, alpha=1)
    rects15 = ax.bar(r5, arena["arena03"], width=barWidth,   color=colorARENA, alpha=1)

  else:
      
    fig, ax = plt.subplots()
    rects11 = ax.bar(r1, dwa["dwa03"], width=barWidth, color=colorDWA, alpha=0.3)
    rects12 = ax.bar(r2, teb["teb03"], width=barWidth,   color=colorTEB, alpha=0.3)
    rects13 = ax.bar(r3, mpc["mpc03"], width=barWidth,   color=colorMPC, alpha=0.3)
    rects14 = ax.bar(r4, cadrl["cadrl03"], width=barWidth,   color=colorCADRL, alpha=0.3)
    rects15 = ax.bar(r5, arena["arena03"], width=barWidth,   color=colorARENA, alpha=0.3)

    rects6 = ax.bar(r1, dwa["dwa02"], width=barWidth,   color=colorDWA, alpha=0.6)
    rects7 = ax.bar(r2, teb["teb02"], width=barWidth,  color=colorTEB, alpha=0.6)
    rects8 = ax.bar(r3, mpc["mpc02"], width=barWidth,   color=colorMPC, alpha=0.6)
    rects9 = ax.bar(r4, cadrl["cadrl02"], width=barWidth,  color=colorCADRL, alpha=0.6)
    rects10 = ax.bar(r5, arena["arena02"], width=barWidth,   color=colorARENA, alpha=0.6)

    rects1 = ax.bar(r1, dwa["dwa01"], width=barWidth, label='dwa',  color=colorDWA, alpha=1, ecolor='black',capsize=2)
    rects2 = ax.bar(r2, teb["teb01"], width=barWidth, label='teb',  color=colorTEB, alpha=1, ecolor='black',capsize=2)
    rects3 = ax.bar(r3, mpc["mpc01"], width=barWidth, label='mpc',  color=colorMPC, alpha=1, ecolor='black',capsize=2)
    rects4 = ax.bar(r4, cadrl["cadrl01"], width=barWidth, label='cadrl',  color=colorCADRL, alpha=1, ecolor='black',capsize=2)
    rects5 = ax.bar(r5, arena["arena01"], width=barWidth, label='arena',  color=colorARENA, alpha=1, ecolor='black',capsize=2)

  


  #captions
  caption = ""
  if metric == "path":
    caption = "avg. Path Lenght [m]"
    title = "Path Lenght"
  if metric == "time":
    caption = "avg. Time t.g. [s]"
    title = "Time t.g."
  if metric == "success":
    caption = "Success"
    title = caption
  if metric == "collisions":
    caption = "Collisions"
    title = caption

  # Add xticks on the middle of the group bars
  plt.xlabel('No. Obstacles', fontsize=15)
  plt.xticks([r + 2*barWidth for r in range(3)], ['5', '10', '20'])
  plt.ylabel('{}'.format(caption), fontsize=15)
  plt.title("{} over No. Obstacles".format(title), fontweight='bold', fontsize=16)

  ax.grid('on')
  # Create legend & Showt graphic
  #plt.legend(loc='upper left')
  plt.savefig('{0}obs_{1}.png'.format(metric,map))
  plt.show()

# %%
# !pip install -q latextable

# %%
from tabulate import tabulate
from texttable import Texttable

import latextable

rows = [['Rocket', 'Organisation', 'LEO Payload (Tonnes)', 'Maiden Flight'],
        ['Saturn V', 'NASA', '140', '1967'],
        ['Space Shuttle', 'NASA', '24.4', '1981'],
        ['Falcon 9 FT-Expended', 'SpaceX', '22.8', '2017'],
        ['Ariane 5 ECA', 'ESA', '21', '2002']]

table = Texttable()
table.set_cols_align(["c"] * 4)
table.set_deco(Texttable.HEADER | Texttable.VLINES)
table.add_rows(rows)

print('Tabulate Table:')
print(tabulate(rows, headers='firstrow'))

print('\nTexttable Table:')
print(table.draw())

print('\nTabulate Latex:')
print(tabulate(rows, headers='firstrow', tablefmt='latex'))

print('\nTexttable Latex:')
print(latextable.draw_latex(table, caption="A comparison of rocket features."))
# Out:
# Tabulate Table:
# Rocket                Organisation      LEO Payload (Tonnes)    Maiden Flight
# --------------------  --------------  ----------------------  ---------------
# Saturn V              NASA                             140               1967
# Space Shuttle         NASA                              24.4             1981
# Falcon 9 FT-Expended  SpaceX                            22.8             2017
# Ariane 5 ECA          ESA                               21               2002
#
# Texttable Table:
#        Rocket        | Organisation | LEO Payload (Tonnes) | Maiden Flight
# =====================+==============+======================+==============
#       Saturn V       |     NASA     |         140          |     1967
#    Space Shuttle     |     NASA     |        24.400        |     1981
# Falcon 9 FT-Expended |    SpaceX    |        22.800        |     2017
#     Ariane 5 ECA     |     ESA      |          21          |     2002
#
# Tabulate Latex:
# ...
